# %%
import pandas as pd

# %%
df = pd.read_csv('latestdata.csv')
# Out:
# C:\Users\Andrea\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (1,2,10,11,13,14,15,16,17,18,19,20,22,23,24,25,26,27,28,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        ID    age   sex              city          province        country  \
# 0  000-1-    NaN   NaN               NaN  Pays de la Loire         France
# 1  000-1-  50-59  male  Snohomish County        Washington  United States
# 2  000-1-    NaN   NaN               NaN               NaN            NaN
# 3  000-1-    NaN   NaN               NaN               NaN            NaN
# 4  000-1-    NaN   NaN               NaN               NaN            NaN
#
#    wuhan(0)_not_wuhan(1)  latitude  longitude geo_resolution  \
# 0                    1.0  47.48646   -0.81128         admin1
# 1                    1.0  48.04818 -121.69600         admin2
# 2                    NaN       NaN        NaN            NaN
# 3                    NaN       NaN        NaN            NaN
# 4                    NaN       NaN        NaN            NaN
#
#            ...          date_death_or_discharge notes_for_discussion location  \
# ...

# %%
dfBoulder = df.loc[df['admin2'] == 'Boulder County']
dfBoulder
# Out:
#                 ID  age  sex            city  province        country  \
# 15994  000-1-25319  NaN  NaN  Boulder County  Colorado  United States
# 15996  000-1-25320  NaN  NaN  Boulder County  Colorado  United States
# 15997  000-1-25321  NaN  NaN  Boulder County  Colorado  United States
#
#        wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  \
# 15994                    1.0  40.092088 -105.357348         admin2
# 15996                    1.0  40.092088 -105.357348         admin2
# 15997                    1.0  40.092088 -105.357348         admin2
#
#                ...          date_death_or_discharge notes_for_discussion  \
# 15994          ...                              NaN                  NaN
# 15996          ...                              NaN                  NaN
# 15997          ...                              NaN                  NaN
#
#       location admin3          admin2    admin1    country_new admin_id  \
# ...

# %%
dfEcuador = df.loc[df['country'] == 'Ecuador']
dfEcuador
# Out:
#                  ID  age     sex                                       city  \
# 4240    000-1-13479  NaN  female  Jose Joaquin de Olmedo Airport, Guayaquil
# 4449    000-1-13659  NaN     NaN                                        NaN
# 4452    000-1-13660  NaN     NaN                                        NaN
# 4453    000-1-13661  NaN     NaN                                        NaN
# 4454    000-1-13662  NaN     NaN                                        NaN
# 4455    000-1-13663  NaN     NaN                                        NaN
# 9514    000-1-17901  NaN     NaN                                        NaN
# 11106   000-1-19333  NaN     NaN                                        NaN
# 33844   000-1-41142  NaN     NaN                                        NaN
# 33845   000-1-41143  NaN     NaN                                        NaN
# 33846   000-1-41144  NaN     NaN                                        NaN
# ...

# %%
dfAges = df.dropna(subset= ["age"])
dfAges
# Out:
#                  ID    age     sex                                   city  \
# 1            000-1-  50-59    male                       Snohomish County
# 7            000-1-  60-69  female                       Snohomish County
# 8            000-1-  50-59    male                       Snohomish County
# 9            000-1-  30-39  female                       Snohomish County
# 10           000-1-  30-39  female                       Snohomish County
# 11          000-1-1     30    male                Chaohu City, Hefei City
# 12          000-1-1  60-69  female                         Whatcom County
# 13         000-1-10  60-69  female                          Pitkin County
# 14         000-1-10     30    male                             Hefei City
# 15        000-1-100     65  female                          Shenzhen City
# 16        000-1-100     44    male                                    NaN
# 19      000-1-10000   8-68     NaN                            Xuzhou City
# ...
